# %% [markdown]
# ## DATA PREPROCESSING AND DATA CLEANING

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('A.csv')
df.head(10)
# Out:
#     LAST_POLL  VMID                                    UUID     dom  \
# 0  1604455173     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 1  1604455142     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 2  1604455113     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 3  1604455082     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 4  1604455055     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 5  1604455024     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 6  1604454997     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 7  1604454962     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 8  1604454935     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
# 9  1604454902     7  "2bc1fde1-28d9-454e-8029-21a138714234"  one-33
#
#    rxbytes_slope  rxpackets_slope  rxerrors_slope  rxdrops_slope  \
# 0        88.2065          30.1414             0.0            0.0
# 1        87.8708          27.3499             0.0            0.0
# ...

# %%
df.tail()
# Out:
#        LAST_POLL  VMID                                  UUID     dom  \
# 9605  1604601182     6  cf1325c0-957a-4744-8912-377f3f477971  one-43
# 9606  1604601152     6  cf1325c0-957a-4744-8912-377f3f477971  one-43
# 9607  1604601122     6  cf1325c0-957a-4744-8912-377f3f477971  one-43
# 9608  1604601092     6  cf1325c0-957a-4744-8912-377f3f477971  one-43
# 9609  1604601062     6  cf1325c0-957a-4744-8912-377f3f477971  one-43
#
#       rxbytes_slope  rxpackets_slope  rxerrors_slope  rxdrops_slope  \
# 9605        88.7897          30.9638             0.0            0.0
# 9606        88.0519          29.5388             0.0            0.0
# 9607        89.1474          45.9392             0.0            0.0
# 9608        87.7974          26.5651             0.0            0.0
# 9609            NaN              NaN             NaN            NaN
#
#       txbytes_slope  txpackets_slope  ...  vdard_bytes_slope  \
# 9605           90.0          89.9974  ...                0.0
# ...

# %%
df.shape
# Out:
# (9610, 44)

# %%
df.size
# Out:
# 422840

# %%
df.columns
# Out:
# Index(['LAST_POLL', 'VMID', 'UUID', 'dom', 'rxbytes_slope', 'rxpackets_slope',
#        'rxerrors_slope', 'rxdrops_slope', 'txbytes_slope', 'txpackets_slope',
#        'txerrors_slope', 'txdrops_slope', 'timecpu_slope', 'timesys_slope',
#        'timeusr_slope', 'state_slope', 'memmax_slope', 'mem_slope',
#        'cpus_slope', 'cputime_slope', 'memactual_slope', 'memswap_in_slope',
#        'memswap_out_slope', 'memmajor_fault_slope', 'memminor_fault_slope',
#        'memunused_slope', 'memavailable_slope', 'memusable_slope',
#        'memlast_update_slope', 'memdisk_cache_slope',
#        'memhugetlb_pgalloc_slope', 'memhugetlb_pgfail_slope', 'memrss_slope',
#        'vdard_req_slope', 'vdard_bytes_slope', 'vdawr_reqs_slope',
#        'vdawr_bytes_slope', 'vdaerror_slope', 'hdard_req_slope',
#        'hdard_bytes_slope', 'hdawr_reqs_slope', 'hdawr_bytes_slope',
#        'hdaerror_slope', 'Status'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       LAST_POLL   VMID   UUID    dom  rxbytes_slope  rxpackets_slope  \
# 0         False  False  False  False          False            False
# 1         False  False  False  False          False            False
# 2         False  False  False  False          False            False
# 3         False  False  False  False          False            False
# 4         False  False  False  False          False            False
# ...         ...    ...    ...    ...            ...              ...
# 9605      False  False  False  False          False            False
# 9606      False  False  False  False          False            False
# 9607      False  False  False  False          False            False
# 9608      False  False  False  False          False            False
# 9609      False  False  False  False           True             True
#
#       rxerrors_slope  rxdrops_slope  txbytes_slope  txpackets_slope  ...  \
# ...

# %%
df = df.dropna()

# %%
df['Status'].unique()
# Out:
# array(['Normal', 'Attack'], dtype=object)

# %%
df.describe()
# Out:
#           LAST_POLL         VMID  rxbytes_slope  rxpackets_slope  \
# count  9.594000e+03  9594.000000    9594.000000      9594.000000
# mean   1.604482e+09     7.551178      88.237795        35.454518
# std    8.162846e+04     1.731400       0.779002        18.590801
# min    1.604406e+09     1.000000      58.392500         1.789900
# 25%    1.604424e+09     6.000000      87.797400        26.565100
# 50%    1.604442e+09     8.000000      87.954600        28.072500
# 75%    1.604589e+09     9.000000      88.264300        30.963800
# max    1.604636e+09    10.000000      89.999900        89.915700
#
#        rxerrors_slope  rxdrops_slope  txbytes_slope  txpackets_slope  \
# count          9594.0         9594.0    9594.000000      9594.000000
# mean              0.0            0.0      31.755948        22.272845
# std               0.0            0.0      41.176777        36.895174
# min               0.0            0.0       0.000000         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9594 entries, 0 to 9608
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   LAST_POLL                 9594 non-null   int64
#  1   VMID                      9594 non-null   int64
#  2   UUID                      9594 non-null   object
#  3   dom                       9594 non-null   object
#  4   rxbytes_slope             9594 non-null   float64
#  5   rxpackets_slope           9594 non-null   float64
#  6   rxerrors_slope            9594 non-null   float64
#  7   rxdrops_slope             9594 non-null   float64
#  8   txbytes_slope             9594 non-null   float64
#  9   txpackets_slope           9594 non-null   float64
#  10  txerrors_slope            9594 non-null   float64
#  11  txdrops_slope             9594 non-null   float64
#  12  timecpu_slope             9594 non-null   float64
# ...

# %%
pd.crosstab(df["Status"], df["rxbytes_slope"])
# Out:
# rxbytes_slope  58.3925  83.4181  84.3258  85.1322  85.4796  85.6013  85.7009  \
# Status
# Attack               0        0        0        0        0        0        0
# Normal               1        1        1        1        1        1        1
#
# rxbytes_slope  85.8448  86.0884  86.0995  ...  89.9964  89.9965  89.9966  \
# Status                                    ...
# Attack               0        0        0  ...        0        0        0
# Normal               1        1        1  ...        2        3        1
#
# rxbytes_slope  89.9988  89.9994  89.9995  89.9996  89.9997  89.9998  89.9999
# Status
# Attack               0        0        0        0        0        0        0
# Normal               1        2        1        2        2        1       16
#
# [2 rows x 1143 columns]

# %%
df.groupby(["Status","rxbytes_slope"]).groups
# Out:
# {('Attack', 87.5617): [8762], ('Attack', 87.7241): [8579, 8663, 8671, 8705, 8741, 8826, 8887, 8909, 8967, 8989, 9017, 9025, 9053, 9082, 9125, 9179, 9245, 9301, 9334], ('Attack', 87.763): [9450], ('Attack', 87.7974): [8464, 8470, 8484, 8487, 8492, 8509, 8516, 8520, 8522, 8535, 8538, 8542, 8570, 8599, 8605, 8639, 8646, 8660, 8666, 8668, 8676, 8678, 8709, 8712, 8714, 8717, 8730, 8746, 8750, 8753, 8759, 8764, 8767, 8770, 8791, 8814, 8816, 8818, 8820, 8828, 8835, 8839, 8884, 8893, 8912, 8924, 8926, 8929, 8938, 8946, 8984, 9000, 9005, 9028, 9032, 9050, 9060, 9066, 9070, 9074, 9078, 9110, 9128, 9134, 9154, 9157, 9160, 9162, 9184, 9188, 9229, 9242, 9268, 9339, 9342, 9410, 9413, 9528, 9530, 9532, 9608], ('Attack', 87.8402): [8460, 8488, 8510, 8521, 8529, 8551, 8559, 8566, 8601, 8688, 8697, 8721, 8725, 8733, 8755, 8771, 8793, 8801, 8810, 8834, 8841, 8858, 8867, 8879, 8901, 8916, 8922, 8933, 8941, 8951, 8959, 8975, 8996, 9003, 9010, 9045, 9062, 9068, 9076, 9105, 9112, 9133, 9187, 9195, 9259, 92
# ...

# %%
df["Status"].value_counts()
# Out:
# Status
# Normal    7288
# Attack    2306
# Name: count, dtype: int64

# %%
pd.Categorical(df["Status"]).describe()
# Out:
#             counts     freqs
# categories
# Attack        2306  0.240359
# Normal        7288  0.759641

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9604    False
# 9605    False
# 9606    False
# 9607    False
# 9608    False
# Length: 9594, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0
